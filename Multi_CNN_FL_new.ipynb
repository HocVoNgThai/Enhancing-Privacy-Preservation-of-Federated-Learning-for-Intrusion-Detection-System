# %%
# init.py
import numpy as np
import pandas as pd
import zipfile
import dask.dataframe as dk
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import mixed_precision
import gc
import tenseal as ts  # <<< THÊM VÀO

# Bật mixed precision
mixed_precision.set_global_policy('mixed_float16')
tf.get_logger().setLevel('ERROR')
tf.config.optimizer.set_jit(True)  # Bật XLA để tối ưu hóa

# Cấu hình Dask Client với giới hạn tài nguyên (12GB RAM)
from dask.distributed import Client
client = Client(n_workers=2, threads_per_worker=2, memory_limit='4GB')
print(client)

# <<< Khởi tạo Homomorphic Encryption Context >>>
print("Đang tạo HE context...")
he_context = ts.context(
    ts.SCHEME_TYPE.CKKS,
    poly_modulus_degree=16384,  # <-- TĂNG LÊN để có sức chứa 8192
    coeff_mod_bit_sizes=[60, 40, 60] # <-- Tối ưu cho độ sâu tính toán nông (1 phép nhân)
)
he_context.generate_galois_keys()
he_context.global_scale = 2**40
print("Đã tạo xong HE context.")
# <<< KẾT THÚC >>>


input_files = [f"file{i+1}" for i in range(3)]
temp_dir = "FL_Data/"
input_files = [temp_dir + output_file for output_file in input_files]
print(input_files)

# Đọc dữ liệu Parquet với Dask, chỉ lấy metadata để giảm tải
df = [dk.read_parquet(file, columns=None) for file in input_files]  # Chỉ đọc metadata
print(df[1].dtypes)

batch_size = 512  # Tăng batch_size để giảm số bước
ratio_test_all = 0.2
features_len = len(df[0].columns) - 1  # Giả định tất cả file có cùng cấu trúc
print("Feature Len:", features_len)

# Ước lượng số lượng mẫu từ metadata thay vì tính chính xác
train_sizes = [df_i.shape[0].compute() * (1 - ratio_test_all) for df_i in df]
val_sizes = [df_i.shape[0].compute() * ratio_test_all * 0.25 for df_i in df]
test_sizes = [df_i.shape[0].compute() * ratio_test_all * 0.75 for df_i in df]

train_dfs = []
val_dfs = []
test_dfs = []
for dff in df:
    train_df, val_test_df = dff.random_split([1 - ratio_test_all, ratio_test_all], shuffle=True)
    test_df, val_df = val_test_df.random_split([0.75, 0.25], shuffle=True)
    train_dfs.append(train_df)
    val_dfs.append(val_df)
    test_dfs.append(test_df)

def dask_to_tf_dataset(dask_df, batch_size, features_len):
    def generator():
        for batch in dask_df.to_delayed():
            batch = batch.compute()
            if batch.empty:
                continue
            X = batch.drop(columns=['label']).values.astype(np.float32)
            y = batch['label'].values.astype(np.int32)
            num_splits = max(1, len(X) // batch_size)
            X_batches = np.array_split(X, num_splits)
            y_batches = np.array_split(y, num_splits)
            for X_batch, y_batch in zip(X_batches, y_batches):
                yield X_batch, y_batch
    output_signature = (
        tf.TensorSpec(shape=(None, features_len), dtype=tf.float32),
        tf.TensorSpec(shape=(None,), dtype=tf.int32),
    )
    dataset = tf.data.Dataset.from_generator(generator, output_signature=output_signature)
    return dataset.cache().prefetch(tf.data.AUTOTUNE).shuffle(buffer_size=1000)

train_gens = [dask_to_tf_dataset(train_df, batch_size, features_len).repeat() for train_df in train_dfs]
val_gens = [dask_to_tf_dataset(val_df, batch_size, features_len).repeat() for val_df in val_dfs]
test_gens = [dask_to_tf_dataset(test_df, batch_size, features_len).repeat() for test_df in test_dfs]

from server_new import Server
from client_new import Client
import datetime

num_servers = 1
num_clients = 3

# Ước lượng steps
stepsPerEpoch_Clients = [int(np.ceil(size / batch_size)) for size in train_sizes]
stepsValidate_Clients = [int(np.ceil(size / batch_size)) for size in val_sizes]
stepsTest_Clients = [int(np.ceil(size / batch_size)) for size in test_sizes]

active_servers_list = ['server_' + str(i) for i in range(num_servers)]
active_clients_list = ['client_' + str(i) for i in range(num_clients)]
print(active_servers_list)
print(active_clients_list)

agents_dict = {}
serverObjects = {server_name: Server(server_name=server_name, active_clients_list=active_clients_list)
                 for server_name in active_servers_list}

# <<< CHỈNH SỬA: Thêm he_context khi khởi tạo Client >>>
clientObjects = {client_name: Client(client_name, train_gens[clientID], val_gens[clientID], test_gens[clientID],
                                     stepsPerEpoch_Clients[clientID], stepsValidate_Clients[clientID], stepsTest_Clients[clientID],
                                     active_clients_list=active_clients_list,
                                     he_context=he_context) # TRUYỀN HE CONTEXT VÀO
                 for clientID, client_name in enumerate(active_clients_list)}
# <<< KẾT THÚC CHỈNH SỬA >>>


temp_dir_log = clientObjects['client_0'].get_temp_dir()
for index, client_name in enumerate(active_clients_list):
    clientObjects[client_name].get_steps_per_epoch()
    clientObjects[client_name].get_validation_steps()
    clientObjects[client_name].get_test_steps()

agents_dict['server'] = serverObjects
agents_dict['client'] = clientObjects

for agent_name, agent in serverObjects.items():
    agent.set_agentsDict(agents_dict=agents_dict)
for agent_name, agent in clientObjects.items():
    agent.set_agentsDict(agents_dict=agents_dict)

# Giải phóng tài nguyên không cần thiết
del train_dfs, val_dfs, test_dfs, df
gc.collect()

server = agents_dict['server']['server_0']
if __name__ == '__main__':
    server.InitLoop()
    server.final_statistics()
    client.close()  # Đóng Dask Client sau khi hoàn tất
# Out:
# 2025-06-28 23:37:43.147412: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-28 23:37:43.158071: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751128663.170701   35930 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751128663.174267   35930 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1751128663.183828   35930 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751128663.183852   35930 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751128663.183853   35930 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751128663.183854   35930 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-28 23:37:43.187413: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <Client: 'tcp://127.0.0.1:40745' processes=2 threads=4, memory=7.45 GiB>
# Đang tạo HE context...
# Đã tạo xong HE context.
# ['FL_Data/file1', 'FL_Data/file2', 'FL_Data/file3']
# flow_duration      float64
# Header_Length      float64
# Protocol Type      float64
# Duration           float64
# Rate               float64
# Srate              float64
# Drate              float64
# fin_flag_number    float64
# syn_flag_number    float64
# rst_flag_number    float64
# psh_flag_number    float64
# ack_flag_number    float64
# ece_flag_number    float64
# cwr_flag_number    float64
# ack_count          float64
# syn_count          float64
# fin_count          float64
# urg_count          float64
# rst_count          float64
# HTTP               float64
# HTTPS              float64
# DNS                float64
# Telnet             float64
# SMTP               float64
# SSH                float64
# IRC                float64
# TCP                float64
# UDP                float64
# DHCP               float64
# ARP                float64
# ICMP               float64
# IPv                float64
# LLC                float64
# Tot sum            float64
# Min                float64
# Max                float64
# AVG                float64
# Std                float64
# Tot size           float64
# IAT                float64
# Number             float64
# Magnitue           float64
# Radius             float64
# Covariance         float64
# Variance           float64
# Weight             float64
# label                int32
# dtype: object
# Feature Len: 46
# I0000 00:00:1751128668.280217   35930 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3539 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# ['server_0']
# ['client_0', 'client_1', 'client_2']
# Train steps: 5338
# Val steps: 334
# Test steps: 1001
# Train steps: 3739
# Val steps: 234
# Test steps: 702
# Train steps: 4262
# Val steps: 267
# Test steps: 800
# ====================================== Đang chạy Iteration 1 ======================================
# Epoch 1/2
# Epoch 1/2
# Epoch 1/2
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751128671.897673   36048 service.cc:152] XLA service 0x7fdbec013270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751128671.897716   36048 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# I0000 00:00:1751128671.904113   36048 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1751128672.023884   36048 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-06-28 23:37:55.718747: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 4559/5338 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9105 - loss: 0.2533
# 2025-06-28 23:38:29.895428: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:29.908789: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:29.930229: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
# 4582/5338 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9107 - loss: 0.2528
# 2025-06-28 23:38:30.291121: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 4862/5338 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9122 - loss: 0.2479
# 2025-06-28 23:38:31.612040: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:31.771469: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
# 4968/5338 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9127 - loss: 0.2461
# 2025-06-28 23:38:32.209190: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
# 5116/5338 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9135 - loss: 0.2438
# 2025-06-28 23:38:32.981327: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:33.126072: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
# 5182/5338 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9138 - loss: 0.2428
# 2025-06-28 23:38:33.433470: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
# 5297/5338 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9143 - loss: 0.2410
# 2025-06-28 23:38:34.061806: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:34.141728: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
# 5331/5338 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9145 - loss: 0.2405
# 2025-06-28 23:38:34.336405: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:34.117010: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:34.300031: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:34.351382: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:35.538110: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:35.948796: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:36.119638: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:36.180245: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:36.242615: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:36.966540: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:37.171018: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.278481: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.364953: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.447641: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.529137: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.610686: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.694660: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.782491: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.865204: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:37.947391: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.029125: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.113734: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.197078: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.283139: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.330741: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:38.364016: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.446270: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.477488: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:38.531740: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.614457: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.693545: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:38.703578: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.787365: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.871456: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:38.953239: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.038653: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.205117: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.288855: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.373766: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.456911: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.540324: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.623748: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.708908: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.791334: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.881218: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:39.966692: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:40.048768: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:40.131003: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:40.476443: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-06-28 23:38:40.542921: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:40.567974: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:41.633523: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:41.717209: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:41.766516: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:42.301686: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:42.391638: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:43.339746: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:43.536740: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:43.605106: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-06-28 23:38:43.753669: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:44.101935: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.205810: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.306754: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.394181: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.479986: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.563369: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.650015: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.739870: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.823537: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.905906: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:44.988041: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.070521: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.154005: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.236401: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.323089: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.406540: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.489295: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.572636: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.656569: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.740774: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.826356: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.907172: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:45.991034: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.075581: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.158179: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.241458: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.322603: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.410326: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.493458: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.574241: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.659912: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.742294: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.827827: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.911694: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:46.995292: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.080397: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.163006: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.245170: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.328064: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.412947: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.500842: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.584166: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.666670: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.749962: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.831626: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.913923: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:47.998656: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.083229: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.166103: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.248181: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.330999: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.413367: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.496286: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.578069: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.660763: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.745015: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.827306: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.911919: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:48.996781: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:49.079827: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:49.161437: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:49.246503: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:49.332172: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:50.505248: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:51.015473: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:51.118504: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:51.250683: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:51.487579: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:51.929200: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:52.635550: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:52.716770: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:52.850506: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:53.378149: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:53.647887: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:53.672363: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:54.028695: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:54.364437: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:54.865294: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:55.025655: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:55.704116: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:55.755684: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:56.129627: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:56.711320: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:57.274649: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:57.416269: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:57.989016: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_124', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:58.487331: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:58.540034: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:58.732276: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:38:58.954621: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 72 bytes spill stores, 72 bytes spill loads
#
# 2025-06-28 23:38:59.080852: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_122', 808 bytes spill stores, 716 bytes spill loads
#
# 2025-06-28 23:38:59.248384: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.352904: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.441985: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.524737: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.608576: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.691441: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.773419: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.855173: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:38:59.937843: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.021343: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.102588: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.186778: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.269085: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.351492: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.433811: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-06-28 23:39:00.516398: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...
# Done model fit
#
# [client_0] Bắt đầu mã hóa tham số theo chunks...
# [client_0] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_0 End Produce Weights
# [client_0] Nhận global model, bắt đầu giải mã các chunks...
# [client_0] Giải mã và tái tạo từ chunks hoàn tất.
# [client_1] Nhận global model, bắt đầu giải mã các chunks...
# [client_2] Nhận global model, bắt đầu giải mã các chunks...
# [client_1] Giải mã và tái tạo từ chunks hoàn tất.
# [client_2] Giải mã và tái tạo từ chunks hoàn tất.
# Đã lưu global model cho iteration 1 tại multiclass_FL_log/Month06-Day28-23h-37p/client_0_log/global_model_iter_1.keras
# Đã lưu global model cho iteration 1 tại multiclass_FL_log/Month06-Day28-23h-37p/client_2_log/global_model_iter_1.keras
# Đã lưu global model cho iteration 1 tại multiclass_FL_log/Month06-Day28-23h-37p/client_1_log/global_model_iter_1.keras
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9533 - loss: 0.1149
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.9526 - loss: 0.1146
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5567 - loss: 0.9112
# 310/800 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8209 - loss: 0.8615Arguments:  Performance Metrics for client_1 on iteration 1
# -------------------------------------------
# local accuracy: 0.9529612064361572
# local loss: 0.1153869777917862
# global accuracy: 0.5561538338661194
# global_loss: 0.911630392074585
# local compute time: 0:01:56.369997
# Simulated time to receive global weights: 0:02:04.807272
#
#
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9518 - loss: 0.1187
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8216 - loss: 0.8617
# Arguments:  Performance Metrics for client_2 on iteration 1
# -------------------------------------------
# local accuracy: 0.9530847072601318
# local loss: 0.11404182016849518
# global accuracy: 0.8220455050468445
# global_loss: 0.8621723055839539
# local compute time: 0:01:53.699104
# Simulated time to receive global weights: 0:02:04.807272
#
#
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5592 - loss: 1.0643
# Arguments:  Performance Metrics for client_0 on iteration 1
# -------------------------------------------
# local accuracy: 0.951606810092926
# local loss: 0.11849654465913773
# global accuracy: 0.559597909450531
# global_loss: 1.0634146928787231
# local compute time: 0:02:03.657438
# Simulated time to receive global weights: 0:02:04.807272
#
#
# [client_0] Simulated time for client set() to finish iteration 1: 0:04:10.706336
#
# [client_1] Simulated time for client set() to finish iteration 1: 0:04:10.706336
#
# [client_2] Simulated time for client set() to finish iteration 1: 0:04:10.706336
#
# ====================================== Kết thúc Iteration 1 ======================================
# ====================================== Đang chạy Iteration 2 ======================================
# Epoch 1/2
# Epoch 1/2
# Epoch 1/2
# 4262/4262 ━━━━━━━━━━━━━━━━━━━━ 35s 7ms/step - accuracy: 0.9421 - loss: 0.1509 - val_accuracy: 0.9554 - val_loss: 0.1083
# Epoch 2/2
# 3739/3739 ━━━━━━━━━━━━━━━━━━━━ 35s 8ms/step - accuracy: 0.9402 - loss: 0.1560 - val_accuracy: 0.9533 - val_loss: 0.1131
# Epoch 2/2
# 5338/5338 ━━━━━━━━━━━━━━━━━━━━ 39s 7ms/step - accuracy: 0.9430 - loss: 0.1484 - val_accuracy: 0.9557 - val_loss: 0.1067
# Epoch 2/2
# 3739/3739 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9530 - loss: 0.1166 - val_accuracy: 0.9553 - val_loss: 0.1082
# 4065/4262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9539 - loss: 0.1136Done model fit
#
# 3170/5338 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9537 - loss: 0.1144[client_1] Bắt đầu mã hóa tham số theo chunks...
# 4078/4262 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9539 - loss: 0.1136[client_1] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_1 End Produce Weights
# 4262/4262 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9540 - loss: 0.1136 - val_accuracy: 0.9568 - val_loss: 0.1064
# 3604/5338 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9538 - loss: 0.1142Done model fit
#
# 3617/5338 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9538 - loss: 0.1142[client_2] Bắt đầu mã hóa tham số theo chunks...
# [client_2] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_2 End Produce Weights
# 5338/5338 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9540 - loss: 0.1137 - val_accuracy: 0.9581 - val_loss: 0.1019
# Done model fit
#
# [client_0] Bắt đầu mã hóa tham số theo chunks...
# [client_0] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_0 End Produce Weights
# [client_0] Nhận global model, bắt đầu giải mã các chunks...
# [client_1] Nhận global model, bắt đầu giải mã các chunks...
# [client_2] Nhận global model, bắt đầu giải mã các chunks...
# [client_0] Giải mã và tái tạo từ chunks hoàn tất.
# [client_2] Giải mã và tái tạo từ chunks hoàn tất.
# [client_1] Giải mã và tái tạo từ chunks hoàn tất.
# Đã lưu global model cho iteration 2 tại multiclass_FL_log/Month06-Day28-23h-37p/client_1_log/global_model_iter_2.keras
# Đã lưu global model cho iteration 2 tại multiclass_FL_log/Month06-Day28-23h-37p/client_0_log/global_model_iter_2.keras
# Đã lưu global model cho iteration 2 tại multiclass_FL_log/Month06-Day28-23h-37p/client_2_log/global_model_iter_2.keras
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9569 - loss: 0.1056
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9559 - loss: 0.1071
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9577 - loss: 0.1033
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9575 - loss: 0.1042
# Arguments:  Performance Metrics for client_1 on iteration 2
# -------------------------------------------
# local accuracy: 0.9572274088859558
# local loss: 0.10487750917673111
# global accuracy: 0.9579418301582336
# global_loss: 0.10396163910627365
# local compute time: 0:00:56.164913
# Simulated time to receive global weights: 0:01:05.978742
#
#
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9563 - loss: 0.1063
# Arguments:  Performance Metrics for client_2 on iteration 2
# -------------------------------------------
# local accuracy: 0.9561675190925598
# local loss: 0.10696513205766678
# global accuracy: 0.9565816521644592
# global_loss: 0.10625775903463364
# local compute time: 0:00:58.452235
# Simulated time to receive global weights: 0:01:05.978742
#
#
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9576 - loss: 0.1038
# Arguments:  Performance Metrics for client_0 on iteration 2
# -------------------------------------------
# local accuracy: 0.957994818687439
# local loss: 0.10300260782241821
# global accuracy: 0.9570424556732178
# global_loss: 0.10461761802434921
# local compute time: 0:01:04.819928
# Simulated time to receive global weights: 0:01:05.978742
#
#
# [client_0] Simulated time for client set() to finish iteration 2: 0:02:13.049276
#
# [client_1] Simulated time for client set() to finish iteration 2: 0:02:13.049276
#
# [client_2] Simulated time for client set() to finish iteration 2: 0:02:13.049276
#
# ====================================== Kết thúc Iteration 2 ======================================
# ====================================== Đang chạy Iteration 3 ======================================
# Epoch 1/2
# Epoch 1/2
# Epoch 1/2
# 3739/3739 ━━━━━━━━━━━━━━━━━━━━ 35s 8ms/step - accuracy: 0.9552 - loss: 0.1103 - val_accuracy: 0.9564 - val_loss: 0.1055
# Epoch 2/2
# 4262/4262 ━━━━━━━━━━━━━━━━━━━━ 35s 7ms/step - accuracy: 0.9562 - loss: 0.1081 - val_accuracy: 0.9587 - val_loss: 0.1006
# Epoch 2/2
# 5338/5338 ━━━━━━━━━━━━━━━━━━━━ 39s 7ms/step - accuracy: 0.9550 - loss: 0.1106 - val_accuracy: 0.9582 - val_loss: 0.1012
# Epoch 2/2
# 3739/3739 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.9557 - loss: 0.1087 - val_accuracy: 0.9576 - val_loss: 0.1037
# 2986/5338 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9564 - loss: 0.1078Done model fit
#
# 3929/4262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9566 - loss: 0.1063[client_1] Bắt đầu mã hóa tham số theo chunks...
# 3930/4262 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9566 - loss: 0.1063[client_1] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_1 End Produce Weights
# 4262/4262 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9566 - loss: 0.1063 - val_accuracy: 0.9591 - val_loss: 0.0997
# 3591/5338 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9564 - loss: 0.1077Done model fit
#
# 3603/5338 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9564 - loss: 0.1077[client_2] Bắt đầu mã hóa tham số theo chunks...
# [client_2] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_2 End Produce Weights
# 5338/5338 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9565 - loss: 0.1074 - val_accuracy: 0.9591 - val_loss: 0.0987
# Done model fit
#
# [client_0] Bắt đầu mã hóa tham số theo chunks...
# [client_0] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_0 End Produce Weights
# [client_0] Nhận global model, bắt đầu giải mã các chunks...
# [client_1] Nhận global model, bắt đầu giải mã các chunks...
# [client_2] Nhận global model, bắt đầu giải mã các chunks...
# [client_2] Giải mã và tái tạo từ chunks hoàn tất.
# [client_1] Giải mã và tái tạo từ chunks hoàn tất.
# [client_0] Giải mã và tái tạo từ chunks hoàn tất.
# Đã lưu global model cho iteration 3 tại multiclass_FL_log/Month06-Day28-23h-37p/client_2_log/global_model_iter_3.keras
# Đã lưu global model cho iteration 3 tại multiclass_FL_log/Month06-Day28-23h-37p/client_0_log/global_model_iter_3.keras
# Đã lưu global model cho iteration 3 tại multiclass_FL_log/Month06-Day28-23h-37p/client_1_log/global_model_iter_3.keras
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9591 - loss: 0.1003
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9589 - loss: 0.1006
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9589 - loss: 0.1003
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9591 - loss: 0.1013
# Arguments:  Performance Metrics for client_1 on iteration 3
# -------------------------------------------
# local accuracy: 0.9591608643531799
# local loss: 0.1002977266907692
# global accuracy: 0.9594632387161255
# global_loss: 0.10018507391214371
# local compute time: 0:00:56.248408
# Simulated time to receive global weights: 0:01:05.749078
#
#
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9590 - loss: 0.1002
#  589/1001 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9589 - loss: 0.1002Arguments:  Performance Metrics for client_2 on iteration 3
# -------------------------------------------
# local accuracy: 0.9587740898132324
# local loss: 0.1007399931550026
# global accuracy: 0.9591116309165955
# global_loss: 0.09988248348236084
# local compute time: 0:00:59.174964
# Simulated time to receive global weights: 0:01:05.749078
#
#
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9587 - loss: 0.1004
# Arguments:  Performance Metrics for client_0 on iteration 3
# -------------------------------------------
# local accuracy: 0.9591077566146851
# local loss: 0.09960242360830307
# global accuracy: 0.9586946368217468
# global_loss: 0.1003289669752121
# local compute time: 0:01:04.592926
# Simulated time to receive global weights: 0:01:05.749078
#
#
# [client_0] Simulated time for client set() to finish iteration 3: 0:02:12.589951
#
# [client_1] Simulated time for client set() to finish iteration 3: 0:02:12.589951
#
# [client_2] Simulated time for client set() to finish iteration 3: 0:02:12.589951
#
# ====================================== Kết thúc Iteration 3 ======================================
# ====================================== Đang chạy Iteration 4 ======================================
# Epoch 1/2
# Epoch 1/2
# Epoch 1/2
# 3739/3739 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9566 - loss: 0.1066 - val_accuracy: 0.9580 - val_loss: 0.1026
# Epoch 2/2
# 4262/4262 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - accuracy: 0.9576 - loss: 0.1044 - val_accuracy: 0.9594 - val_loss: 0.0986
# Epoch 2/2
# 5338/5338 ━━━━━━━━━━━━━━━━━━━━ 41s 7ms/step - accuracy: 0.9571 - loss: 0.1060 - val_accuracy: 0.9596 - val_loss: 0.0982
# Epoch 2/2
# 3739/3739 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.9570 - loss: 0.1056 - val_accuracy: 0.9581 - val_loss: 0.1020
# 3116/5338 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9572 - loss: 0.1052Done model fit
# 3860/4262 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9580 - loss: 0.1033
# 3864/4262 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9580 - loss: 0.1033[client_1] Bắt đầu mã hóa tham số theo chunks...
# [client_1] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# 3865/4262 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9580 - loss: 0.1033client_1 End Produce Weights
# 4262/4262 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9580 - loss: 0.1033 - val_accuracy: 0.9594 - val_loss: 0.0979
# 3782/5338 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9572 - loss: 0.1051Done model fit
#
# 3793/5338 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9572 - loss: 0.1051[client_2] Bắt đầu mã hóa tham số theo chunks...
# 3794/5338 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9572 - loss: 0.1051[client_2] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_2 End Produce Weights
# 5338/5338 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9573 - loss: 0.1050 - val_accuracy: 0.9599 - val_loss: 0.0972
# Done model fit
#
# [client_0] Bắt đầu mã hóa tham số theo chunks...
# [client_0] Mã hóa 12 weight chunks và 1 bias chunks hoàn tất.
# client_0 End Produce Weights
# [client_0] Nhận global model, bắt đầu giải mã các chunks...
# [client_1] Nhận global model, bắt đầu giải mã các chunks...
# [client_1] Giải mã và tái tạo từ chunks hoàn tất.
# [client_2] Nhận global model, bắt đầu giải mã các chunks...
# [client_0] Giải mã và tái tạo từ chunks hoàn tất.
# [client_2] Giải mã và tái tạo từ chunks hoàn tất.
# Đã lưu global model cho iteration 4 tại multiclass_FL_log/Month06-Day28-23h-37p/client_1_log/global_model_iter_4.keras
# Đã lưu global model cho iteration 4 tại multiclass_FL_log/Month06-Day28-23h-37p/client_2_log/global_model_iter_4.keras
# Đã lưu global model cho iteration 4 tại multiclass_FL_log/Month06-Day28-23h-37p/client_0_log/global_model_iter_4.keras
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9596 - loss: 0.0985
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9601 - loss: 0.0976
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9601 - loss: 0.0975
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9594 - loss: 0.0992
# Arguments:  Performance Metrics for client_1 on iteration 4
# -------------------------------------------
# local accuracy: 0.9598095417022705
# local loss: 0.09869054704904556
# global accuracy: 0.9591901898384094
# global_loss: 0.0998193621635437
# local compute time: 0:00:57.263367
# Simulated time to receive global weights: 0:01:07.946921
#
#
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9596 - loss: 0.0989
# Arguments:  Performance Metrics for client_2 on iteration 4
# -------------------------------------------
# local accuracy: 0.959598958492279
# local loss: 0.09851442277431488
# global accuracy: 0.960034966468811
# global_loss: 0.09755092114210129
# local compute time: 0:01:00.631265
# Simulated time to receive global weights: 0:01:07.946921
#
#
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9601 - loss: 0.0970
# Arguments:  Performance Metrics for client_0 on iteration 4
# -------------------------------------------
# local accuracy: 0.9597957730293274
# local loss: 0.09805658459663391
# global accuracy: 0.9599944949150085
# global_loss: 0.09758106619119644
# local compute time: 0:01:06.784478
# Simulated time to receive global weights: 0:01:07.946921
#
#
# [client_0] Simulated time for client set() to finish iteration 4: 0:02:16.985634
#
# [client_1] Simulated time for client set() to finish iteration 4: 0:02:16.985634
#
# [client_2] Simulated time for client set() to finish iteration 4: 0:02:16.985634
#
# ====================================== Kết thúc Iteration 4 ======================================
# {}
# Client's Accuracies are {'client_0': [0.9586946368217468, 0.9599944949150085], 'client_1': [0.9594632387161255, 0.9591901898384094], 'client_2': [0.9591116309165955, 0.960034966468811]}

# %%
import os
from tensorflow.keras.models import load_model
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# Giả định các biến global như tempdirs, active_clients_list, test_gens, stepsTest_Clients đã được định nghĩa
tempdirs = [temp_dir_log + f"/client_{i}_log/" for i in range(len(active_clients_list))]

# Tự động xác định số iteration cho từng client
model_names_template = [f"global_model_iter_{i+1}.keras" for i in range(8)]  # Danh sách tiềm năng
actual_iterations = {}
for i, client_dir in enumerate(tempdirs):
    existing_models = [m for m in model_names_template if os.path.exists(client_dir + m)]
    if existing_models:
        current_max = max([int(m.split('_')[-1].split('.')[0]) for m in existing_models])
        actual_iterations[f'client_{i}'] = current_max
    else:
        actual_iterations[f'client_{i}'] = 8  # Mặc định 8 nếu không tìm thấy tệp
model_names = {f'client_{i}': [f"global_model_iter_{j}.keras" for j in range(1, actual_iterations[f'client_{i}'] + 1)] for i in range(len(active_clients_list))}
Iterations = {f'client_{i}': [f"Iteration {j}" for j in range(1, actual_iterations[f'client_{i}'] + 1)] for i in range(len(active_clients_list))}
print(f"Detected iterations: {actual_iterations}")

# Load models
models = {}
for i, client_name in enumerate(active_clients_list):
    models[client_name] = [load_model(tempdirs[i] + model_name) for model_name in model_names[client_name]]
print(models['client_0'])
# Out:
# Detected iterations: {'client_0': 4, 'client_1': 4, 'client_2': 4}
# /home/th/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'loss_scale_optimizer', because it has 34 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /home/th/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 30 variables whereas the saved optimizer has 0 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# [<Sequential name=sequential, built=True>, <Sequential name=sequential, built=True>, <Sequential name=sequential, built=True>, <Sequential name=sequential, built=True>]

# %%
# Client 0
precisions = []
recalls = []
f1s = []

X_test = []
y_test = []
for X_batch, y_batch in test_gens[0].take(stepsTest_Clients[0]):
    X_test.append(X_batch.numpy())
    y_test.append(y_batch.numpy())
X_test = np.concatenate(X_test, axis=0)
y_test = np.concatenate(y_test, axis=0)

print(len(X_test))
for iteration in range(actual_iterations['client_0']):
    print(models['client_0'][iteration])
    y_pred_pre = models['client_0'][iteration].predict(X_test, verbose=1)
    y_pred = np.argmax(y_pred_pre, axis=1)
    
    precisions.append(precision_score(y_test, y_pred, average='macro'))
    recalls.append(recall_score(y_test, y_pred, average='macro'))
    f1s.append(f1_score(y_test, y_pred, average='macro'))
print("Precision Score: ", precisions)
print("Recall Score: ", recalls)
print("F1 Score: ", f1s)

# Vẽ biểu đồ Precision, Recall, F1-score
plt.figure(figsize=(8, 5))
plt.plot(Iterations['client_0'], precisions, marker='o', linestyle='-', label="Precision", color='blue')
plt.plot(Iterations['client_0'], recalls, marker='s', linestyle='-', label="Recall", color='red')
plt.plot(Iterations['client_0'], f1s, marker='^', linestyle='-', label="F1-score", color='green')
plt.xlabel("Model")
plt.ylabel("Score")
plt.title("Precision, Recall, F1-score over different iterations _ CLIENT 0")
plt.legend()
plt.grid(True)
plt.savefig(tempdirs[0] + "/pre_recall_f1.png", dpi=300, bbox_inches="tight")
plt.show()

attack_types = ['Benign', 'DDos', 'Mirai', 'Spoofing', 'Reconnaissance']
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=attack_types, yticklabels=attack_types)
plt.yticks(rotation=360)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix CLIENT 0")
plt.savefig(tempdirs[0] + "/confusion_matrix.png", dpi=300, bbox_inches="tight")
plt.show()

# Tính và vẽ TP, FP, TN, FN
metrics = []
num_classes = len(attack_types)
for i in range(num_classes):
    TP = cm[i, i]
    FP = cm[:, i].sum() - TP
    FN = cm[i, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)
    metrics.append([attack_types[i], TP, FP, TN, FN])

df_metrics = pd.DataFrame(metrics, columns=["Attack_Types", "TP", "FP", "TN", "FN"])
fig, ax = plt.subplots(figsize=(10, 3))
ax.axis("off")
table_data = [[f"{x:,.0f}" if isinstance(x, (int, float)) else x for x in row] for row in df_metrics.values]
table = ax.table(cellText=table_data, colLabels=df_metrics.columns, loc="center", cellLoc="center",
                 colColours=["#f0f0f0"] * len(df_metrics.columns))
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)
ax.set_title("Table of TP, FP, TN, FN - CLIENT 0")
#plt.tight_layout(pad=0.5)
plt.savefig(tempdirs[0] + "/table_tp_fp_tn_fn.png", dpi=300, bbox_inches="tight")
plt.show()

df_metrics[["TP", "FP", "TN", "FN"]] = df_metrics[["TP", "FP", "TN", "FN"]].div(
    df_metrics[["TP", "FP", "TN", "FN"]].sum(axis=1), axis=0
) * 100

fig, ax = plt.subplots(figsize=(18, 8))
bottom = np.zeros(len(df_metrics))
colors = ["#FF9999", "#66B2FF", "#99FF99", "#FFCC99"]

for metric, color in zip(["TP", "FP", "TN", "FN"], colors):
    bars = ax.bar(df_metrics["Attack_Types"], df_metrics[metric], width=0.5, label=metric, bottom=bottom, color=color)
    for i, bar in enumerate(bars):
        height = bar.get_height()
        if height > 0:
            y_pos = bottom[i] + height / 2
            if height < 1:
                y_pos += 0.5
            ax.text(bar.get_x() + bar.get_width() / 2, y_pos,
                    f'{height:.3f}%', ha="center", va="center", rotation=0,
                    fontsize=8, color="black")
    bottom += df_metrics[metric]

ax.set_xlabel("Class", fontsize=12)
ax.set_ylabel("Percentage (%)", fontsize=12)
ax.set_title("Stacked Bar Chart of TP, FP, TN, FN - CLIENT 0", fontsize=15)
ax.set_xticklabels(df_metrics["Attack_Types"], rotation=45, fontsize=12)
ax.legend(loc="upper right", fontsize=12, bbox_to_anchor=(1.15, 1))
#plt.tight_layout(pad=1.0)
plt.savefig(tempdirs[0] + "/stacked_bar_chart_tp_fp_tn_fn.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# 2025-06-28 23:44:05.682339: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 517084
# <Sequential name=sequential, built=True>
# 2025-06-28 23:44:06.014761: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 2025-06-28 23:44:06.227398: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-06-28 23:44:06.495873: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 256 bytes spill stores, 256 bytes spill loads
#
# 2025-06-28 23:44:06.633217: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-06-28 23:44:06.772747: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 292 bytes spill stores, 292 bytes spill loads
# 16127/16159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2025-06-28 23:44:25.352620: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-06-28 23:44:25.614050: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-06-28 23:44:25.624454: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 272 bytes spill stores, 272 bytes spill loads
#
# 2025-06-28 23:44:25.701543: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_105', 384 bytes spill stores, 384 bytes spill loads
# 16159/16159 ━━━━━━━━━━━━━━━━━━━━ 20s 1ms/step
# <Sequential name=sequential, built=True>
# 16159/16159 ━━━━━━━━━━━━━━━━━━━━ 17s 1ms/step
# <Sequential name=sequential, built=True>
# 16159/16159 ━━━━━━━━━━━━━━━━━━━━ 18s 1ms/step
# <Sequential name=sequential, built=True>
# 16159/16159 ━━━━━━━━━━━━━━━━━━━━ 20s 1ms/step
# Precision Score:  [0.5453673609947078, 0.8971453144574693, 0.8991973497007676, 0.8969305331106113]
# Recall Score:  [0.3454541885957572, 0.8303553934666269, 0.8370923403032524, 0.8445720597011152]
# F1 Score:  [0.27904168578321803, 0.8531899147552149, 0.858956371817747, 0.8639684620199803]
# /tmp/ipykernel_35930/3875102694.py:99: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_metrics["Attack_Types"], rotation=45, fontsize=12)

# %%
# Lặp cho Client 1 và Client 2
for client_idx in [1, 2]:
    precisions = []
    recalls = []
    f1s = []

    X_test = []
    y_test = []
    for X_batch, y_batch in test_gens[client_idx].take(stepsTest_Clients[client_idx]):
        X_test.append(X_batch.numpy())
        y_test.append(y_batch.numpy())
    X_test = np.concatenate(X_test, axis=0)
    y_test = np.concatenate(y_test, axis=0)

    print(len(X_test))
    for iteration in range(actual_iterations[f'client_{client_idx}']):
        print(models[f'client_{client_idx}'][iteration])
        y_pred_pre = models[f'client_{client_idx}'][iteration].predict(X_test, verbose=1)
        y_pred = np.argmax(y_pred_pre, axis=1)
        
        precisions.append(precision_score(y_test, y_pred, average='macro'))
        recalls.append(recall_score(y_test, y_pred, average='macro'))
        f1s.append(f1_score(y_test, y_pred, average='macro'))
    print(f"Precision Score Client {client_idx}: ", precisions)
    print(f"Recall Score Client {client_idx}: ", recalls)
    print(f"F1 Score Client {client_idx}: ", f1s)

    # Vẽ biểu đồ Precision, Recall, F1-score
    plt.figure(figsize=(8, 5))
    plt.plot(Iterations[f'client_{client_idx}'], precisions, marker='o', linestyle='-', label="Precision", color='blue')
    plt.plot(Iterations[f'client_{client_idx}'], recalls, marker='s', linestyle='-', label="Recall", color='red')
    plt.plot(Iterations[f'client_{client_idx}'], f1s, marker='^', linestyle='-', label="F1-score", color='green')
    plt.xlabel("Model")
    plt.ylabel("Score")
    plt.title(f"Precision, Recall, F1-score over different iterations _ CLIENT {client_idx}")
    plt.legend()
    plt.grid(True)
    plt.savefig(tempdirs[client_idx] + "/pre_recall_f1.png", dpi=300, bbox_inches="tight")
    plt.show()

    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(12, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=attack_types, yticklabels=attack_types)
    plt.yticks(rotation=360)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix CLIENT {client_idx}")
    plt.savefig(tempdirs[client_idx] + "/confusion_matrix.png", dpi=300, bbox_inches="tight")
    plt.show()

    metrics = []
    for i in range(num_classes):
        TP = cm[i, i]
        FP = cm[:, i].sum() - TP
        FN = cm[i, :].sum() - TP
        TN = cm.sum() - (TP + FP + FN)
        metrics.append([attack_types[i], TP, FP, TN, FN])

    df_metrics = pd.DataFrame(metrics, columns=["Attack_Types", "TP", "FP", "TN", "FN"])
    fig, ax = plt.subplots(figsize=(10, 3))
    ax.axis("off")
    table_data = [[f"{x:,.0f}" if isinstance(x, (int, float)) else x for x in row] for row in df_metrics.values]
    table = ax.table(cellText=table_data, colLabels=df_metrics.columns, loc="center", cellLoc="center",
                     colColours=["#f0f0f0"] * len(df_metrics.columns))
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1.2, 1.2)
    ax.set_title(f"Table of TP, FP, TN, FN - CLIENT {client_idx}")
    #plt.tight_layout(pad=1.0)
    plt.savefig(tempdirs[client_idx] + "/table_tp_fp_tn_fn.png", dpi=300, bbox_inches="tight")
    plt.show()

    df_metrics[["TP", "FP", "TN", "FN"]] = df_metrics[["TP", "FP", "TN", "FN"]].div(
        df_metrics[["TP", "FP", "TN", "FN"]].sum(axis=1), axis=0
    ) * 100

    fig, ax = plt.subplots(figsize=(18, 8))
    bottom = np.zeros(len(df_metrics))
    colors = ["#FF9999", "#66B2FF", "#99FF99", "#FFCC99"]

    for metric, color in zip(["TP", "FP", "TN", "FN"], colors):
        bars = ax.bar(df_metrics["Attack_Types"], df_metrics[metric], width=0.5, label=metric, bottom=bottom, color=color)
        for i, bar in enumerate(bars):
            height = bar.get_height()
            if height > 0:
                y_pos = bottom[i] + height / 2
                if height < 1:
                    y_pos += 0.5
                ax.text(bar.get_x() + bar.get_width() / 2, y_pos,
                        f'{height:.3f}%', ha="center", va="center", rotation=0,
                        fontsize=8, color="black")
        bottom += df_metrics[metric]

    ax.set_xlabel("Class", fontsize=12)
    ax.set_ylabel("Percentage (%)", fontsize=12)
    ax.set_title(f"Stacked Bar Chart of TP, FP, TN, FN - CLIENT {client_idx}", fontsize=15)
    ax.set_xticklabels(df_metrics["Attack_Types"], rotation=45, fontsize=12)
    ax.legend(loc="upper right", fontsize=12, bbox_to_anchor=(1.15, 1))
    #plt.tight_layout(pad=1.0)
    plt.savefig(tempdirs[client_idx] + "/stacked_bar_chart_tp_fp_tn_fn.png", dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# 2025-06-28 23:45:34.135105: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 362899
# <Sequential name=sequential_1, built=True>
# 11316/11341 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2025-06-28 23:45:46.843051: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-06-28 23:45:47.133319: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-06-28 23:45:47.166241: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 272 bytes spill stores, 272 bytes spill loads
#
# 2025-06-28 23:45:47.214528: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 384 bytes spill stores, 384 bytes spill loads
# 11341/11341 ━━━━━━━━━━━━━━━━━━━━ 14s 1ms/step
# <Sequential name=sequential_1, built=True>
# 11341/11341 ━━━━━━━━━━━━━━━━━━━━ 14s 1ms/step
# <Sequential name=sequential_1, built=True>
# 11341/11341 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step
# <Sequential name=sequential_1, built=True>
# 11341/11341 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step
# Precision Score Client 1:  [0.6251815030921043, 0.8957896728292252, 0.8988346904766248, 0.9013826358556788]
# Recall Score Client 1:  [0.33084525469193676, 0.8339264490817018, 0.8399700872063349, 0.8382025033132612]
# F1 Score Client 1:  [0.2947726833651809, 0.8557456179073224, 0.8610973681063159, 0.8599173644539653]
# /tmp/ipykernel_35930/3207210425.py:97: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_metrics["Attack_Types"], rotation=45, fontsize=12)
# 414258
# <Sequential name=sequential_2, built=True>
# 12942/12946 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2025-06-28 23:46:50.492713: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-06-28 23:46:50.588203: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 384 bytes spill stores, 384 bytes spill loads
#
# 2025-06-28 23:46:50.594266: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 272 bytes spill stores, 272 bytes spill loads
#
# 2025-06-28 23:46:50.602299: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 16 bytes spill stores, 16 bytes spill loads
# 12946/12946 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step
# <Sequential name=sequential_2, built=True>
# 12946/12946 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step
# <Sequential name=sequential_2, built=True>
# 12946/12946 ━━━━━━━━━━━━━━━━━━━━ 14s 1ms/step
# <Sequential name=sequential_2, built=True>
# 12946/12946 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step
# Precision Score Client 2:  [0.6779575220073626, 0.8917474163465231, 0.891510636541953, 0.8993004877478994]
# Recall Score Client 2:  [0.5622420741777252, 0.8325749409028089, 0.8412669302089469, 0.8413236886136748]
# F1 Score Client 2:  [0.5612090658636455, 0.8536078778543155, 0.8599310351953655, 0.8621520278655048]
# /tmp/ipykernel_35930/3207210425.py:97: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_metrics["Attack_Types"], rotation=45, fontsize=12)

# %%
# Phần vẽ biểu đồ log (đã điều chỉnh để tự động tính số epoch)
log_names = {f'client_{i}': [f"Iteration_{j+1}.csv" for j in range(actual_iterations[f'client_{i}'])] for i in range(len(active_clients_list))}
print(f"Log files: {log_names}")

for i in range(len(active_clients_list)):
    all_logs = []
    for log_name in log_names[f'client_{i}']:
        file_path = tempdirs[i] + log_name
        if not os.path.exists(file_path):
            print(f"File {file_path} không tồn tại!")
            continue
        log_part = pd.read_csv(file_path)
        all_logs.append(log_part)

    if not all_logs:
        print(f"No log files found for client_{i}, skipping log plots.")
        continue

    log_df = pd.concat(all_logs, ignore_index=True)
    epochs = range(1, len(log_df) + 1)
    total_epochs = len(log_df)
    epochs_per_iteration = total_epochs // actual_iterations[f'client_{i}']  # Tính số epoch trung bình mỗi iteration

    plt.figure(figsize=(16, 10))

    # Training Accuracy
    plt.subplot(2, 2, 1)
    plt.plot(epochs, log_df['accuracy'], 'b-', label='Training Accuracy')
    plt.margins(y=0.1)  # Thêm khoảng cách 10% trên cùng để chứa nhãn
    max_acc = max(log_df['accuracy']) if not log_df['accuracy'].empty else 1.0
    for iter_idx in range(1, actual_iterations[f'client_{i}']):
        boundary_epoch = iter_idx * epochs_per_iteration  # Vị trí đường gạch dựa trên số epoch thực tế
        plt.axvline(x=boundary_epoch, color='gray', linestyle='-', linewidth=2, alpha=0.9)
        y_pos = max_acc
        if iter_idx < actual_iterations[f'client_{i}'] - 1:
            plt.text(boundary_epoch - 2, y_pos, f'Iter {iter_idx}', rotation=0, verticalalignment='bottom', fontsize=10, fontweight='bold')
        else:
            plt.text(boundary_epoch - 2, y_pos, f'Iter {iter_idx}    (Last)', rotation=0, verticalalignment='bottom', fontsize=10, fontweight='bold')
    plt.title(f'Training Accuracy Client {i}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend()

    # Validation Accuracy
    plt.subplot(2, 2, 3)
    plt.plot(epochs, log_df['val_accuracy'], 'g-', label='Validation Accuracy')
    plt.margins(y=0.1)  # Thêm khoảng cách 10% trên cùng để chứa nhãn
    max_val_acc = max(log_df['val_accuracy']) if not log_df['val_accuracy'].empty else 1.0
    for iter_idx in range(1, actual_iterations[f'client_{i}']):
        boundary_epoch = iter_idx * epochs_per_iteration  # Vị trí đường gạch dựa trên số epoch thực tế
        plt.axvline(x=boundary_epoch, color='gray', linestyle='-', linewidth=2, alpha=0.9)
        y_pos = max_val_acc
        if iter_idx < actual_iterations[f'client_{i}'] - 1:
            plt.text(boundary_epoch - 2, y_pos, f'Iter {iter_idx}', rotation=0, verticalalignment='bottom', fontsize=10, fontweight='bold')
        else:
            plt.text(boundary_epoch - 2, y_pos, f'Iter {iter_idx}    (Last)', rotation=0, verticalalignment='bottom', fontsize=10, fontweight='bold')
    plt.title(f'Validation Accuracy Client {i}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend()

    # Training Loss
    plt.subplot(2, 2, 2)
    plt.plot(epochs, log_df['loss'], 'r-', label='Training Loss')
    for iter_idx in range(1, actual_iterations[f'client_{i}']):
        boundary_epoch = iter_idx * epochs_per_iteration  # Vị trí đường gạch dựa trên số epoch thực tế
        plt.axvline(x=boundary_epoch, color='gray', linestyle='-', linewidth=2, alpha=0.9)
        if iter_idx < actual_iterations[f'client_{i}'] - 1:
            plt.text(boundary_epoch - 2, max(log_df['loss']) * 0.95, f'Iter {iter_idx}', rotation=0, verticalalignment='top', fontsize=10, fontweight='bold')
        else:
            plt.text(boundary_epoch - 2, max(log_df['loss']) * 0.95, f'Iter {iter_idx}    (Last)', rotation=0, verticalalignment='top', fontsize=10, fontweight='bold')
    plt.title(f'Training Loss Client {i}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()

    # Validation Loss
    plt.subplot(2, 2, 4)
    plt.plot(epochs, log_df['val_loss'], 'm-', label='Validation Loss')
    for iter_idx in range(1, actual_iterations[f'client_{i}']):
        boundary_epoch = iter_idx * epochs_per_iteration  # Vị trí đường gạch dựa trên số epoch thực tế
        plt.axvline(x=boundary_epoch, color='gray', linestyle='-', linewidth=2, alpha=0.9)
        if iter_idx < actual_iterations[f'client_{i}'] - 1:
            plt.text(boundary_epoch - 2, max(log_df['val_loss']) * 0.95, f'Iter {iter_idx}', rotation=0, verticalalignment='top', fontsize=10, fontweight='bold')
        else:
            plt.text(boundary_epoch - 2, max(log_df['val_loss']) * 0.95, f'Iter {iter_idx}    (Last)', rotation=0, verticalalignment='top', fontsize=10, fontweight='bold')
    plt.title(f'Validation Loss Client {i}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.savefig(tempdirs[i] + "/train_valid_acc_loss.png", dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# Log files: {'client_0': ['Iteration_1.csv', 'Iteration_2.csv', 'Iteration_3.csv', 'Iteration_4.csv'], 'client_1': ['Iteration_1.csv', 'Iteration_2.csv', 'Iteration_3.csv', 'Iteration_4.csv'], 'client_2': ['Iteration_1.csv', 'Iteration_2.csv', 'Iteration_3.csv', 'Iteration_4.csv']}

# %%
# Phần vẽ local/global evaluation
for i in range(len(active_clients_list)):
    file_path_local = tempdirs[i] + "local_val.csv"
    file_path_global = tempdirs[i] + "global_val.csv"
  
    local_val = pd.read_csv(file_path_local)
    global_val = pd.read_csv(file_path_global)
    plt.figure(figsize=(16, 10))
    plt.subplot(2, 2, 1)
    plt.plot(Iterations[f'client_{i}'], local_val['local_acc'], marker='o', linestyle='-', label="Local Acc", color='blue')
    plt.plot(Iterations[f'client_{i}'], global_val['global_acc'], marker='s', linestyle='-', label="Global Acc", color='red')
    plt.xlabel("Iteration")
    plt.ylabel("Score")
    plt.title(f"Local and Global Evaluation Accuracy Client {i}")
    plt.legend()
    plt.grid(True)

    plt.subplot(2, 2, 2)
    plt.plot(Iterations[f'client_{i}'], local_val['local_loss'], marker='o', linestyle='-', label="Local Loss", color='green')
    plt.plot(Iterations[f'client_{i}'], global_val['global_loss'], marker='s', linestyle='-', label="Global Loss", color='purple')
    plt.xlabel("Iteration")
    plt.ylabel("Score")
    plt.title(f"Local and Global Evaluation Loss Client {i}")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.savefig(tempdirs[i] + "/evaluation_acc_loss.png", dpi=300, bbox_inches="tight")
    plt.show()

# %% [markdown]
# #Client 2
#
# precisions = []
# recalls = []
# f1s = []
#
# #Iterations = [f"Iteration {index+1}" for index in range(5)]
#
# X_test = []
# y_test = []
# for X_batch, y_batch in test_gens[2].take(stepsTest_Clients[2]):
#     X_test.append(X_batch.numpy())
#     y_test.append(y_batch.numpy())
# X_test = np.concatenate(X_test, axis=0)
# y_test = np.concatenate(y_test, axis=0)
#
# print(len(X_test))
# for iteration in range(len(Iterations)):
#     print(models['client_2'][iteration])
#     y_pred_pre = models['client_2'][iteration].predict(X_test, verbose=1)
#     y_pred = np.argmax(y_pred_pre, axis=1)
#
#     precisions.append(precision_score(y_test, y_pred, average='macro'))
#     recalls.append(recall_score(y_test, y_pred, average='macro'))
#     f1s.append(f1_score(y_test, y_pred, average='macro'))
# print("Precision Score: ", precisions)
# print("Recall Score: ", recalls)
# print("F1 Score: ", f1s)
#
#
# # Vẽ biểu đồ
# plt.figure(figsize=(8, 5))
# plt.plot(Iterations, precisions, marker='o', linestyle='-', label="Precision", color='blue')
# plt.plot(Iterations, recalls, marker='s', linestyle='-', label="Recall", color='red')
# plt.plot(Iterations, f1s, marker='^', linestyle='-', label="F1-score", color='green')
#
# # Thêm tiêu đề và nhãn
# plt.xlabel("Model")
# plt.ylabel("Score")
# plt.title("Precision, Recall, F1-score over different iterations _ CLIENT 2")
# plt.legend()
# plt.grid(True)
#
# # Hiển thị đồ thị
# plt.savefig(tempdirs[2]+ "/pre_recall_f1.png", dpi=300, bbox_inches="tight")
# plt.show()
#
#
# attack_types =['Benign', 'DDos', 'Mirai', 'Spoofing', 'Reconnaissance']
# cm = confusion_matrix(y_test, y_pred)
#     # Vẽ heatmap
# plt.figure(figsize=(12, 7))
# sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=attack_types, yticklabels=attack_types)
# plt.yticks(rotation=360)
# # Thêm nhãn
# plt.xlabel("Predicted Label")
# plt.ylabel("True Label")
# plt.title("Confusion Matrix CLIENT 2")
#
# # Hiển thị
# plt.savefig(tempdirs[2]+ "/confusion_matrix.png", dpi=300, bbox_inches="tight")
# plt.show()
#
# # Tính TP, FP, TN, FN
# metrics = []
# num_classes = len(attack_types)
# for i in range(num_classes):
#     TP = cm[i, i]
#     FP = cm[:, i].sum() - TP
#     FN = cm[i, :].sum() - TP
#     TN = cm.sum() - (TP + FP + FN)
#     metrics.append([attack_types[i], TP, FP, TN, FN])
#
# # Chuyển thành DataFrame
# df_metrics = pd.DataFrame(metrics, columns=["Attack_Types", "TP", "FP", "TN", "FN"])
#
# # Vẽ bảng
# fig, ax = plt.subplots(figsize=(10, 3))
# ax.axis("off")
# table_data = [[f"{x:,.0f}" if isinstance(x, (int, float)) else x for x in row] for row in df_metrics.values]
# table = ax.table(cellText=table_data, colLabels=df_metrics.columns, loc="center", cellLoc="center",
#                  colColours=["#f0f0f0"] * len(df_metrics.columns))
# table.auto_set_font_size(False)
# table.set_fontsize(10)
# table.scale(1.2, 1.2)
# ax.set_title("Table of TP, FP, TN, FN - CLIENT 2", fontsize=12, pad=5)
#
# plt.tight_layout(pad=1.0)
# plt.savefig(tempdirs[2]+ "/table_tp_fp_tn_fn.png", dpi=300, bbox_inches="tight")
# plt.show()
#
# ## Chuẩn hóa dữ liệu (tính tỷ lệ phần trăm)
# df_metrics[["TP", "FP", "TN", "FN"]] = df_metrics[["TP", "FP", "TN", "FN"]].div(
#     df_metrics[["TP", "FP", "TN", "FN"]].sum(axis=1), axis=0
# ) * 100
#
# # Vẽ biểu đồ cột chồng với sửa lỗi vị trí nhãn
# fig, ax = plt.subplots(figsize=(18, 8))  # Tăng kích thước để có không gian hơn
# bottom = np.zeros(len(df_metrics))
# colors = ["#FF9999", "#66B2FF", "#99FF99", "#FFCC99"]
#
# for metric, color in zip(["TP", "FP", "TN", "FN"], colors):
#     bars = ax.bar(df_metrics["Attack_Types"], df_metrics[metric], width=0.5, label=metric, bottom=bottom, color=color)
#     for i, bar in enumerate(bars):
#         height = bar.get_height()
#         if height > 0:
#             # Đặt nhãn ở giữa phần hiện tại dựa trên bottom và height
#             y_pos = bottom[i] + height / 2  # Căn giữa nhãn trong phần hiện tại
#             if height < 1:
#                 y_pos += 0.5
#             ax.text(bar.get_x() + bar.get_width() / 2, y_pos,
#                     f'{height:.3f}%', ha="center", va="center", rotation=0,  # Chữ nằm ngang
#                     fontsize=8, color="black")
#     bottom += df_metrics[metric]  # Cập nhật bottom cho phần tiếp theo
#
# ax.set_xlabel("Class", fontsize=8)
# ax.set_ylabel("Percentage (%)", fontsize=8)
# ax.set_title("Stacked Bar Chart of TP, FP, TN, FN - CLIENT 2", fontsize=10, pad=5)
# ax.set_xticklabels(df_metrics["Attack_Types"], rotation=45, fontsize=8)
# ax.legend(loc="upper right", fontsize=8, bbox_to_anchor=(1.15, 1))
#
# plt.tight_layout(pad=1.0)
# plt.savefig(tempdirs[2]+ "/stacked_bar_chart_tp_fp_tn_fn.png", dpi=300, bbox_inches="tight")
# plt.show()
