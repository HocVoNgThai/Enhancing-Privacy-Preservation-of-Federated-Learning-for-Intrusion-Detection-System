# %%
import numpy as np
import pandas as pd
import dask.dataframe as dk
import tensorflow as tf
from tensorflow.keras.utils import Sequence, to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import regularizers

file_path = "combined_multiclass.csv"

df = dk.read_csv(file_path)
import matplotlib.pyplot as plt
# Đếm số lượng mỗi nhãn

label_counts = df['label'].value_counts().compute()
print(label_counts)
"""
ordered_labels = [0,1]
ordered_counts = [label_counts.get(label,0) for label in ordered_labels]

labels = ["Benign", "Malicious"]
# Vẽ biểu đồ cột
plt.figure(figsize=(9, 5))
plt.bar(labels, ordered_counts, color='skyblue', edgecolor='black')
plt.xlabel("Nhãn (Classes)")
plt.ylabel("Số lượng mẫu (Frequency)")
plt.title("Tỷ lệ nhãn trong Dataset")
plt.xticks(range(len(labels)) ,labels, rotation =45)
plt.show()
"""
# Out:
# 2025-06-01 19:36:53.046259: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-01 19:36:53.067582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748781413.081166  256636 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748781413.085874  256636 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748781413.100081  256636 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748781413.100097  256636 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748781413.100099  256636 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748781413.100100  256636 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-01 19:36:53.104854: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# label
# 2    2634124
# 3     486504
# 1    4000000
# 4     317183
# 0    1098195
# Name: count, dtype: int64
# '\nordered_labels = [0,1]\nordered_counts = [label_counts.get(label,0) for label in ordered_labels]\n\nlabels = ["Benign", "Malicious"]\n# Vẽ biểu đồ cột\nplt.figure(figsize=(9, 5))\nplt.bar(labels, ordered_counts, color=\'skyblue\', edgecolor=\'black\')\nplt.xlabel("Nhãn (Classes)")\nplt.ylabel("Số lượng mẫu (Frequency)")\nplt.title("Tỷ lệ nhãn trong Dataset")\nplt.xticks(range(len(labels)) ,labels, rotation =45)\nplt.show()\n'
# /home/th/miniconda3/envs/tf/lib/python3.9/site-packages/dask/dataframe/core.py:8153: UserWarning: Insufficient elements for `head`. 8000000 elements requested, only 213435 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(

# %%
"""
Kiểm tra dataset sau khi xử lý
"""
#df = dk.read_csv("single_file.csv")

# Tính tổng số mẫu
total_samples = df.shape[0].compute()
print(f"Tổng số mẫu: {total_samples}")
    
# Tính phân bố label
label_counts = df['label'].value_counts().compute()
print("Phân bố label:")
print(label_counts.sort_index())
    
# Kiểm tra số lượng label liên tiếp
df_small = df.head(8000000)
labels = df_small['label'].values
max_consecutive = current = 1  

for i in range(1, len(labels)):
    if labels[i] == labels[i-1]:
        current += 1
        max_consecutive = max(max_consecutive, current)
    else:
        current = 1  # Reset bộ đếm khi label thay đổi

print(f"Chuỗi liên tiếp dài nhất trong 11 triệu mẫu đầu: {max_consecutive}")
# Out:
# Tổng số mẫu: 8536006
# Phân bố label:
# label
# 0    1098195
# 1    4000000
# 2    2634124
# 3     486504
# 4     317183
# Name: count, dtype: int64
# Chuỗi liên tiếp dài nhất trong 11 triệu mẫu đầu: 622

# %%
#Global var 
batch_size = 512
ratio_test_all = 0.20

from dask_ml.model_selection import train_test_split 
# chia train test ratio 0.8:0.2 & random 
'''
def standardize_dask_df(dask_df):
    scaler = StandardScaler()
    X = dask_df.drop(columns=['label']).compute().values
    scaler.fit(X)
    for part in dask_df.to_delayed():
        part = part.compute()
        if part.empty:
            continue
        X_part = part.drop(columns=['label']).values
        X_scaled = scaler.transform(X_part)
        part.iloc[:, :-1] = X_scaled
        yield part

scaled_parts = list(standardize_dask_df(df))
scaled_df = dk.from_pandas(pd.concat(scaled_parts), npartitions=df.npartitions)
scaled_df.to_csv("scaled_output.csv", single_file=True, index=False)
print("Đã in thành công")
'''
train_df, val_test_df = train_test_split(df, test_size=ratio_test_all, random_state=42)
val_df, test_df = train_test_split(val_test_df, test_size=0.85, random_state=42)

# # load từng batch
def dask_to_tf_dataset(dask_df, batch_size): 
    def generator():
        for batch in dask_df.to_delayed():
            batch = batch.compute()  
            if batch.empty:
                continue

            X = batch.drop(columns='label').values.astype(np.float32)
            y = batch['label'].values.astype(np.int32)  # nhị phân: 0 hoặc 1

            num_splits = max(1, len(X) // batch_size)
            X_batches = np.array_split(X, num_splits)
            y_batches = np.array_split(y, num_splits)

            for X_batch, y_batch in zip(X_batches, y_batches):
                yield X_batch, y_batch

    output_signature = ( 
        tf.TensorSpec(shape=(None, 46), dtype=tf.float32), 
        tf.TensorSpec(shape=(None,), dtype=tf.int32),  # không phải one-hot nữa
    )
    
    return tf.data.Dataset.from_generator(generator, output_signature=output_signature).prefetch(tf.data.AUTOTUNE)
# Out:
# /home/th/miniconda3/envs/tf/lib/python3.9/site-packages/dask_ml/model_selection/_split.py:464: FutureWarning: The default value for 'shuffle' must be specified when splitting DataFrames. In the future DataFrames will automatically be shuffled within blocks prior to splitting. Specify 'shuffle=True' to adopt the future behavior now, or 'shuffle=False' to retain the previous behavior.
#   warnings.warn(
# /home/th/miniconda3/envs/tf/lib/python3.9/site-packages/dask_ml/model_selection/_split.py:464: FutureWarning: The default value for 'shuffle' must be specified when splitting DataFrames. In the future DataFrames will automatically be shuffled within blocks prior to splitting. Specify 'shuffle=True' to adopt the future behavior now, or 'shuffle=False' to retain the previous behavior.
#   warnings.warn(

# %%
train_gen = dask_to_tf_dataset(train_df, 512).repeat()
test_gen = dask_to_tf_dataset(test_df, 512)
val_gen = dask_to_tf_dataset(val_df, 512).repeat()
# Out:
# I0000 00:00:1748781430.976696  256636 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3539 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import math
n_samples =  np.ceil(train_df.shape[0])
steps_per_epoch = int(n_samples / (batch_size))
validation_steps = int(steps_per_epoch / (16))
print("Steps/Epoch: ", steps_per_epoch)
num_samples_test = test_df.shape[0].compute()
# Tính số batch
num_batches_test = int(np.ceil(num_samples_test / batch_size))
print("Batch test: ", num_batches_test)
# Out:
# Steps/Epoch:  13339
# Batch test:  2833

# %%
from datetime import datetime, timedelta
import sys, os
# shape
features, labels = next(iter(train_gen))
input_shape = (features.shape[1], 1)
# output_shape = labels.shape[1]

print(f"Input Shape: {input_shape}")

from tensorflow import keras

start_time = datetime.now()

"""model = keras.Sequential([
    layers.Input(shape=input_shape),
    #layers.Conv1D(filters=32, kernel_size=7, padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.05)),
    layers.Conv1D(filters=32, kernel_size=3, padding="same", activation="relu"),
    layers.MaxPooling1D(pool_size=2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),   
    layers.BatchNormalization(),
    layers.Dense(5, activation='softmax')
])"""
model = keras.Sequential([
    layers.Input(shape=input_shape),
    #layers.Conv1D(filters=32, kernel_size=7, padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.05)),
    layers.Conv1D(filters=128, kernel_size=3, padding="same", activation="relu"),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.5),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(5, activation='softmax')
])
adam_optimizer = optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer= adam_optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

from tensorflow.keras.callbacks import CSVLogger
os.makedirs("log_mono", exist_ok=True)
log_name = "log_mono/"+ datetime.now().strftime("%Hh%Mp__%d-%m-%Y")+".csv"
csv_logger = CSVLogger(log_name , append=True)
model.fit(train_gen, epochs=30, validation_data=val_gen, validation_steps= validation_steps , steps_per_epoch= steps_per_epoch, verbose = 1, callbacks=[csv_logger])


end_time = datetime.now()
simulated_time = end_time - start_time
model_name = "saved_model/cnn_model_2-0_batch512_" + datetime.now().strftime("%Hh%Mp__%d-%m-%Y")+".keras"
# Lưu mô hình
model.save(model_name)

print(f"Simulated time: {simulated_time}")
# Out:
# Input Shape: (46, 1)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 46, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 23, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2944)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       376,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 378,629 (1.44 MB)
#  Trainable params: 378,373 (1.44 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748781445.804319  256719 service.cc:152] XLA service 0x7ff90c015680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748781445.804373  256719 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2025-06-01 19:37:25.825136: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1748781445.934153  256719 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-06-01 19:37:27.024482: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-06-01 19:37:27.154269: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 172 bytes spill stores, 172 bytes spill loads
#
# 2025-06-01 19:37:27.192057: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-06-01 19:37:27.193730: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-06-01 19:37:27.200217: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943_0', 164 bytes spill stores, 164 bytes spill loads
#
# 2025-06-01 19:37:27.245370: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-06-01 19:37:27.252093: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 1328 bytes spill stores, 1328 bytes spill loads
#
# 2025-06-01 19:37:27.334396: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 1004 bytes spill stores, 1004 bytes spill loads
#
# 2025-06-01 19:37:27.588027: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 1208 bytes spill stores, 1208 bytes spill loads
#
# 2025-06-01 19:37:27.811654: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 6204 bytes spill stores, 6204 bytes spill loads
#    42/13339 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 0.2010 - loss: 2.1941
# I0000 00:00:1748781449.512545  256719 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   176/13339 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.2034 - loss: 2.1576
# 2025-06-01 19:37:30.694384: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-06-01 19:37:30.856598: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 660 bytes spill stores, 660 bytes spill loads
#
# 2025-06-01 19:37:31.202600: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943_0', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-06-01 19:37:31.313377: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 28 bytes spill stores, 28 bytes spill loads
#   992/13339 ━━━━━━━━━━━━━━━━━━━━ 1:20 7ms/step - accuracy: 0.2198 - loss: 2.0043
# 2025-06-01 19:37:36.912392: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-06-01 19:37:37.276617: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-06-01 19:37:37.364224: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 1004 bytes spill stores, 1004 bytes spill loads
#
# 2025-06-01 19:37:37.543861: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-06-01 19:37:37.593001: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 356 bytes spill stores, 356 bytes spill loads
#
# 2025-06-01 19:37:37.600147: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 172 bytes spill stores, 172 bytes spill loads
#
# 2025-06-01 19:37:37.634516: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943_0', 164 bytes spill stores, 164 bytes spill loads
#
# 2025-06-01 19:37:37.829555: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 1328 bytes spill stores, 1328 bytes spill loads
#
# 2025-06-01 19:37:37.881849: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 1208 bytes spill stores, 1208 bytes spill loads
#
# 2025-06-01 19:37:38.285057: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_943', 6204 bytes spill stores, 6204 bytes spill loads
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - accuracy: 0.4355 - loss: 1.4670 - val_accuracy: 0.6256 - val_loss: 0.9939
# Epoch 2/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.6167 - loss: 1.0285 - val_accuracy: 0.6300 - val_loss: 0.9392
# Epoch 3/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - accuracy: 0.6295 - loss: 0.9317 - val_accuracy: 0.6374 - val_loss: 0.8592
# Epoch 4/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.6444 - loss: 0.8627 - val_accuracy: 0.6550 - val_loss: 0.7963
# Epoch 5/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.6645 - loss: 0.8046 - val_accuracy: 0.6728 - val_loss: 0.7441
# Epoch 6/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.7095 - loss: 0.7400 - val_accuracy: 0.8866 - val_loss: 0.5516
# Epoch 7/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.8625 - loss: 0.5462 - val_accuracy: 0.9000 - val_loss: 0.3451
# Epoch 8/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.8839 - loss: 0.4090 - val_accuracy: 0.9087 - val_loss: 0.2776
# Epoch 9/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.8979 - loss: 0.3297 - val_accuracy: 0.9189 - val_loss: 0.2317
# Epoch 10/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9074 - loss: 0.2840 - val_accuracy: 0.9206 - val_loss: 0.2175
# Epoch 11/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.9126 - loss: 0.2599 - val_accuracy: 0.9225 - val_loss: 0.2032
# Epoch 12/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.9161 - loss: 0.2441 - val_accuracy: 0.9247 - val_loss: 0.1942
# Epoch 13/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.9184 - loss: 0.2306 - val_accuracy: 0.9254 - val_loss: 0.1908
# Epoch 14/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - accuracy: 0.9203 - loss: 0.2199 - val_accuracy: 0.9267 - val_loss: 0.1903
# Epoch 15/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - accuracy: 0.9217 - loss: 0.2132 - val_accuracy: 0.9257 - val_loss: 0.1900
# Epoch 16/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9228 - loss: 0.2083 - val_accuracy: 0.9279 - val_loss: 0.1804
# Epoch 17/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9234 - loss: 0.2045 - val_accuracy: 0.9285 - val_loss: 0.1780
# Epoch 18/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.9239 - loss: 0.2015 - val_accuracy: 0.9286 - val_loss: 0.1802
# Epoch 19/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9245 - loss: 0.1987 - val_accuracy: 0.9289 - val_loss: 0.1787
# Epoch 20/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9249 - loss: 0.1963 - val_accuracy: 0.9287 - val_loss: 0.1752
# Epoch 21/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - accuracy: 0.9253 - loss: 0.1941 - val_accuracy: 0.9288 - val_loss: 0.1787
# Epoch 22/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - accuracy: 0.9259 - loss: 0.1918 - val_accuracy: 0.9296 - val_loss: 0.1731
# Epoch 23/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9262 - loss: 0.1901 - val_accuracy: 0.9292 - val_loss: 0.1758
# Epoch 24/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9267 - loss: 0.1885 - val_accuracy: 0.9305 - val_loss: 0.1738
# Epoch 25/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.9267 - loss: 0.1874 - val_accuracy: 0.9299 - val_loss: 0.1776
# Epoch 26/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 71s 5ms/step - accuracy: 0.9272 - loss: 0.1863 - val_accuracy: 0.9308 - val_loss: 0.1747
# Epoch 27/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9272 - loss: 0.1856 - val_accuracy: 0.9308 - val_loss: 0.1771
# Epoch 28/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 73s 5ms/step - accuracy: 0.9274 - loss: 0.1847 - val_accuracy: 0.9298 - val_loss: 0.1761
# Epoch 29/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9277 - loss: 0.1837 - val_accuracy: 0.9313 - val_loss: 0.1739
# Epoch 30/30
# 13339/13339 ━━━━━━━━━━━━━━━━━━━━ 72s 5ms/step - accuracy: 0.9279 - loss: 0.1827 - val_accuracy: 0.9321 - val_loss: 0.1720
# Simulated time: 0:36:09.502589

# %%
from tensorflow.keras.models import load_model
#model_name = "saved_model/cnn_model_2-0_batch512_11h59p__27-05-2025.keras"
model = load_model(model_name)

output = model.evaluate(test_gen, steps = num_batches_test)
print(f'Loss: {output[0]} Acc: {output[1]}')
# Out:
# 2833/2833 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9322 - loss: 0.1702
# Loss: 0.17111451923847198 Acc: 0.9319510459899902
# 2025-06-01 20:13:53.369955: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-06-01 20:13:53.370064: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# 2025-06-01 20:13:53.370084: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 16696021444389290461
# 2025-06-01 20:13:53.370101: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous recv item cancelled. Key hash: 16260834587007858347
# /home/th/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt

# Load mô hình
model = load_model(model_name)

# Khởi tạo danh sách để lưu nhãn thực tế và nhãn dự đoán
y_true_all = []
y_pred_all = []

# Lặp qua các batch trong test_gen
for X_batch, y_batch in test_gen.take(num_batches_test):
    # Chuyển nhãn thực tế thành danh sách và làm phẳng
    y_true = y_batch.numpy()
    if len(y_true.shape) > 1:  # Nếu y_batch có dạng (batch_size, num_classes)
        y_true = np.argmax(y_true, axis=1)  # Chuyển từ one-hot hoặc xác suất thành nhãn
    else:
        y_true = y_true.flatten()  # Đảm bảo làm phẳng nếu cần
    y_true_all.extend(y_true)

    # Dự đoán với mô hình
    y_pred_prob = model.predict(X_batch, verbose=0)
    # Chuyển xác suất thành nhãn bằng argmax (cho phân loại đa lớp)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_pred_all.extend(y_pred)

# Kiểm tra số lượng mẫu
print("Số lượng mẫu y_true_all:", len(y_true_all))
print("Số lượng mẫu y_pred_all:", len(y_pred_all))

# Tính các chỉ số đánh giá
precision = precision_score(y_true_all, y_pred_all, average='macro')
recall = recall_score(y_true_all, y_pred_all, average='macro')
f1 = f1_score(y_true_all, y_pred_all, average='macro')

print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)

# Vẽ biểu đồ
param_names = ['Precision', 'Recall', 'F1-Score']
array = [precision, recall, f1]

x = np.arange(len(param_names))
width = 0.2  # Độ rộng của mỗi cột
plt.figure(figsize=(8, 5))
plt.bar(param_names, array, color=['blue', 'green', 'red'])

# Cấu hình trục và nhãn
plt.ylabel("Score")
plt.title("Precision, Recall, and F1-Score")
plt.ylim(0, 1)  # Giá trị từ 0 đến 1
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Hiển thị biểu đồ
plt.show()
# Out:
# Số lượng mẫu y_true_all: 1450162
# Số lượng mẫu y_pred_all: 1450162
# Precision: 0.8502466637125086
# Recall: 0.7387219567540155
# F1-Score: 0.7614569271225735

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Tạo ma trận nhầm lẫn
cm = confusion_matrix(y_true_all, y_pred_all)

attack_types =['Benign', 'DDos', 'Mirai', 'Spoofing', 'Reconnaissance']
# Vẽ heatmap
plt.figure(figsize=(10, 7))
# sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=range(cm.shape[0]), yticklabels=range(cm.shape[0))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=attack_types, yticklabels=attack_types)

# Thêm nhãn
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

# Hiển thị
plt.show()


metrics = []
num_classes = len(attack_types)

# Duyệt từng lớp để tính TP, FP, TN, FN
for i in range(num_classes):
    TP = cm[i, i]
    FP = cm[:, i].sum() - TP
    FN = cm[i, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)
    
    metrics.append([attack_types[i], TP, FP, TN, FN])

# Chuyển thành DataFrame
df_metrics = pd.DataFrame(metrics, columns=["Attack_Types", "TP", "FP", "TN", "FN"])
# Vẽ biểu đồ
df_metrics.set_index("Attack_Types").plot(kind="bar", figsize=(12, 5), colormap="viridis")

# Thêm nhãn
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("TP, FP, TN, FN for Each Class")
plt.xticks(rotation=0)
plt.legend(["TP", "FP", "TN", "FN"])

# Hiển thị
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Đọc log từ file CSV
log_df = pd.read_csv(log_name)  # Đổi tên file nếu cần

epochs = range(1, len(log_df) + 1)

plt.figure(figsize=(16, 10))

# Accuracy
plt.subplot(2, 2, 1)
plt.plot(epochs, log_df['accuracy'], 'b-', label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
#plt.ylim(0.40, 1.0)

# Loss
plt.subplot(2, 2, 2)
plt.plot(epochs, log_df['loss'], 'r-', label='Training Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Validation Accuracy
plt.subplot(2, 2, 3)
plt.plot(epochs, log_df['val_accuracy'], 'g-', label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
#plt.ylim(0.95, 1.0)

# Validation Loss
plt.subplot(2, 2, 4)
plt.plot(epochs, log_df['val_loss'], 'm-', label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import joblib  # Để lưu scaler

# Đọc dataset huấn luyện
X_train = df.drop(columns=['label']).values  # Loại bỏ cột label
print(X_train)
# Fit scaler
scaler = StandardScaler()
scaler.fit(X_train)

# Lưu scaler vào file
joblib.dump(scaler, 'scaler.pkl')
print("Scaler đã được huấn luyện và lưu vào 'scaler.pkl'")
# Out:
# dask.array<values, shape=(nan, 46), dtype=float64, chunksize=(nan, 46), chunktype=numpy.ndarray>
