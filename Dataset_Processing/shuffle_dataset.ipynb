# %%
import numpy as np
import pandas as pd
import dask.dataframe as dk
import tensorflow as tf
file_path = "/mnt/d/DoAnChuyenNganh_Train/data/remapping_dataset_2type.csv"
out_path =  "/mnt/d/DoAnChuyenNganh_Train/data/shuffled_remapping_dataset_2type.csv"

df = dk.read_csv(file_path)
# df = df.drop(columns=['Variance', 'Weight'])
print(df.dtypes)
print(df.head(10))
# Out:
# flow_duration      float64
# Header_Length      float64
# Protocol Type      float64
# Duration           float64
# Rate               float64
# Srate              float64
# Drate              float64
# fin_flag_number    float64
# syn_flag_number    float64
# rst_flag_number    float64
# psh_flag_number    float64
# ack_flag_number    float64
# ece_flag_number    float64
# cwr_flag_number    float64
# ack_count          float64
# syn_count          float64
# fin_count          float64
# urg_count          float64
# rst_count          float64
# HTTP               float64
# HTTPS              float64
# DNS                float64
# Telnet             float64
# SMTP               float64
# SSH                float64
# IRC                float64
# TCP                float64
# UDP                float64
# DHCP               float64
# ARP                float64
# ICMP               float64
# IPv                float64
# LLC                float64
# Tot sum            float64
# Min                float64
# Max                float64
# AVG                float64
# Std                float64
# Tot size           float64
# IAT                float64
# Number             float64
# Magnitue           float64
# Radius             float64
# Covariance         float64
# Variance           float64
# Weight             float64
# label                int64
# dtype: object
#    flow_duration  Header_Length  Protocol Type  Duration          Rate  \
# 0       0.556297          75.74           6.11     65.91      1.330350
# 1       0.000000          54.00           6.00     64.00      4.053363
# 2       0.000000          54.00           6.00     64.00     17.566184
# 3       0.000367          54.70           6.00     65.73    103.358151
# 4       0.000000          54.00           6.00     64.00     18.809888
# 5       0.068402       20975.00          17.00     64.00   6126.932326
# 6       0.000000          54.00           6.00     64.00      9.899523
# 7       0.064230       37625.00          17.00     64.00  11711.641407
# 8       0.000000          54.00           6.00     64.00      1.861368
# 9       0.019840       13165.00          17.00     64.00  14606.699957
#
#           Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  \
# 0      1.330350    0.0              0.0              1.0              0.0
# 1      4.053363    0.0              0.0              0.0              0.0
# 2     17.566184    0.0              0.0              0.0              0.0
# 3    103.358151    0.0              0.0              0.0              0.0
# 4     18.809888    0.0              0.0              0.0              0.0
# 5   6126.932326    0.0              0.0              0.0              0.0
# 6      9.899523    0.0              1.0              0.0              1.0
# 7  11711.641407    0.0              0.0              0.0              0.0
# 8      1.861368    0.0              1.0              0.0              1.0
# 9  14606.699957    0.0              0.0              0.0              0.0
#
#    ...       Std  Tot size           IAT  Number   Magnitue    Radius  \
# 0  ...  1.179734     55.76  8.336550e+07     9.5  10.418444  1.681716
# 1  ...  0.000000     54.00  8.303770e+07     9.5  10.392305  0.000000
# 2  ...  0.000000     54.00  8.333083e+07     9.5  10.392305  0.000000
# 3  ...  0.111768     54.08  8.331392e+07     9.5  10.394984  0.158670
# 4  ...  0.000000     54.00  8.307602e+07     9.5  10.392305  0.000000
# 5  ...  0.000000     50.00  8.312381e+07     9.5  10.000000  0.000000
# 6  ...  0.000000     54.00  8.334826e+07     9.5  10.392305  0.000000
# 7  ...  0.000000     50.00  8.309779e+07     9.5  10.000000  0.000000
# 8  ...  0.000000     54.00  8.334816e+07     9.5  10.392305  0.000000
# 9  ...  0.000000     50.00  8.310663e+07     9.5  10.000000  0.000000
#
#    Covariance  Variance  Weight  label
# 0   47.143033      0.03  141.55      1
# 1    0.000000      0.00  141.55      1
# 2    0.000000      0.00  141.55      1
# 3    0.210158      0.06  141.55      1
# 4    0.000000      0.00  141.55      1
# 5    0.000000      0.00  141.55      1
# 6    0.000000      0.00  141.55      1
# 7    0.000000      0.00  141.55      1
# 8    0.000000      0.00  141.55      1
# 9    0.000000      0.00  141.55      1
#
# [10 rows x 47 columns]

# %%
from dask_ml.model_selection import train_test_split 
from sklearn.utils import shuffle

def shuffle_dask_dataframe(df, random_state=None):
    return (
        df.map_partitions(
            lambda part: part.assign(__shuffle_key=np.random.RandomState(random_state).random(len(part)))
        )
        .shuffle('__shuffle_key')
        .drop(columns='__shuffle_key')
    )
    
df = shuffle_dask_dataframe(df)

print(df.dtypes)
print(df.npartitions)
print(df.head(20))
# Out:
# flow_duration      float64
# Header_Length      float64
# Protocol Type      float64
# Duration           float64
# Rate               float64
# Srate              float64
# Drate              float64
# fin_flag_number    float64
# syn_flag_number    float64
# rst_flag_number    float64
# psh_flag_number    float64
# ack_flag_number    float64
# ece_flag_number    float64
# cwr_flag_number    float64
# ack_count          float64
# syn_count          float64
# fin_count          float64
# urg_count          float64
# rst_count          float64
# HTTP               float64
# HTTPS              float64
# DNS                float64
# Telnet             float64
# SMTP               float64
# SSH                float64
# IRC                float64
# TCP                float64
# UDP                float64
# DHCP               float64
# ARP                float64
# ICMP               float64
# IPv                float64
# LLC                float64
# Tot sum            float64
# Min                float64
# Max                float64
# AVG                float64
# Std                float64
# Tot size           float64
# IAT                float64
# Number             float64
# Magnitue           float64
# Radius             float64
# Covariance         float64
# Variance           float64
# Weight             float64
# label                int64
# dtype: object
# 22
#      flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 8         0.019724           1.74           1.04     65.27    18.777409
# 19       40.596896     2289759.80           6.00     64.00    54.127517
# 43       28.143275      371944.60           5.50    182.90    97.607169
# 87        0.029659        9445.00          17.00     64.00  6409.388565
# 97       35.749529      107734.40           9.30    121.70    12.847192
# 120      34.146447     2783094.30           6.00    215.20    82.306505
# 133      65.746522     4897241.80           6.00    114.40    71.037978
# 149      27.468144     1517235.40           6.00     96.10    56.641309
# 186       0.000000          54.00           6.00     64.00     4.109545
# 219       9.151690       24358.20           7.10    124.80    60.949648
# 224      45.362326      519056.30           5.90     86.10    11.844089
# 237      12.415887      150723.20           5.40    157.80    76.170666
# 245      26.323546     2111586.40           7.10     61.80    72.996886
# 252      56.007727     4140260.60           6.00     64.00    70.124252
# 297       4.038954      679712.50           6.00    213.20   131.595614
# 322      20.992395      415210.20           7.10    105.70    31.716813
# 327      42.306627     2947796.60           6.00     63.60    64.456202
# 345       0.000000           0.00           1.00     64.00    33.168615
# 370       3.797932        8592.70          10.00     89.20    24.274946
# 399       0.366073     1253254.80           6.00     87.60  3807.453315
#
#            Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  \
# 8      18.777409    0.0              0.0              0.0              0.0
# 19     54.127517    0.0              0.0              0.0              0.0
# 43     97.607169    0.0              0.0              0.0              0.0
# 87   6409.388565    0.0              0.0              0.0              0.0
# 97     12.847192    0.0              0.0              0.0              0.0
# 120    82.306505    0.0              0.0              0.0              0.0
# 133    71.037978    0.0              0.0              0.0              0.0
# 149    56.641309    0.0              0.0              0.0              0.0
# 186     4.109545    0.0              0.0              0.0              0.0
# 219    60.949648    0.0              0.0              0.0              0.0
# 224    11.844089    0.0              0.0              0.0              0.0
# 237    76.170666    0.0              0.0              0.0              0.0
# 245    72.996886    0.0              0.0              0.0              0.0
# 252    70.124252    0.0              0.0              0.0              0.0
# 297   131.595614    0.0              0.0              0.0              0.0
# 322    31.716813    0.0              0.0              0.0              0.0
# 327    64.456202    0.0              0.0              0.0              0.0
# 345    33.168615    0.0              0.0              0.0              0.0
# 370    24.274946    0.0              0.0              0.0              0.0
# 399  3807.453315    0.0              0.0              0.0              0.0
#
#      ...          Std  Tot size           IAT  Number   Magnitue       Radius  \
# 8    ...     1.123961     42.34  8.312837e+07     9.5   9.202676     1.592094
# 19   ...   471.499083   1378.20  6.959581e-03     5.5  49.897364   666.800398
# 43   ...    15.396909     77.00  1.232970e-02     5.5  11.953314    21.774518
# 87   ...     0.000000     50.00  8.312355e+07     9.5  10.000000     0.000000
# 97   ...   359.382045    123.10  1.665170e+08    13.5  20.757007   509.284607
# 120  ...     3.819212     67.10  1.438808e-03     5.5  11.671680     5.401181
# 133  ...  1479.922809   2672.40  4.770994e-04     5.5  51.006635  2092.926907
# 149  ...   998.096110   1369.20  3.588295e-03     5.5  34.090056  1411.521055
# 186  ...     0.000000     54.00  8.306413e+07     9.5  10.392305     0.000000
# 219  ...  1545.960701    149.90  1.665206e+08    13.5  37.476382  2191.338891
# 224  ...    48.310341    113.80  1.665239e+08    13.5  13.441097    68.427098
# 237  ...   930.731600    508.80  4.689789e-03     5.5  46.774486  1316.253252
# 245  ...   397.193894   1562.10  4.870176e-04     5.5  57.746111   561.716992
# 252  ...   665.247876   1803.60  1.665239e+08    13.5  62.630318   942.304551
# 297  ...   118.506566     64.80  1.665192e+08    13.5  14.611839   167.943852
# 322  ...    64.941194    158.10  1.665214e+08    13.5  13.366309    92.136322
# 327  ...   231.573447   1514.00  3.475094e-03     5.5  54.298154   327.494309
# 345  ...     0.000000     42.00  8.315032e+07     9.5   9.165151     0.000000
# 370  ...    46.813415    111.40  1.665220e+08    13.5  14.259898    66.207961
# 399  ...   788.703823    917.20  1.665177e+08    13.5  40.544636  1117.021349
#
#        Covariance  Variance  Weight  label
# 8    5.197573e+00      0.25  141.55      1
# 19   2.543472e+05      0.90   38.50      0
# 43   4.760677e+02      0.50   38.50      0
# 87   0.000000e+00      0.00  141.55      1
# 97   1.304234e+05      1.00  244.60      0
# 120  1.668833e+01      0.90   38.50      0
# 133  2.749568e+06      0.80   38.50      0
# 149  1.665946e+06      0.60   38.50      0
# 186  0.000000e+00      0.00  141.55      1
# 219  2.415659e+06      1.00  244.60      0
# 224  2.428422e+03      1.00  244.60      0
# 237  9.810409e+05      0.90   38.50      0
# 245  2.691153e+05      0.60   38.50      0
# 252  4.444918e+05      1.00  244.60      0
# 297  1.419595e+04      1.00  244.60      0
# 322  5.993973e+03      1.00  244.60      0
# 327  1.371341e+05      0.40   38.50      0
# 345  0.000000e+00      0.00  141.55      1
# 370  2.211737e+03      1.00  244.60      0
# 399  6.502985e+05      1.00  244.60      0
#
# [20 rows x 47 columns]

# %%
header = True
for i in range(df.npartitions):
    df.get_partition(i).compute().to_csv(out_path, mode='a', header = header, index=False)
    header = False
